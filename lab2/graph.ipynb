# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# sns.set(style="darkgrid")

df = pd.read_csv('res_mutex.csv', delimiter=',')
display(df)
plt.plot(df["Threads"], df["Time"])


# df = pd.read_csv('res2.csv', delimiter=',')
# display(df)
# plt.plot(df["N"], df["Time"])
# Out:
#     Threads   Time     Uskor  Efficiency
# 0         1  2.256  1.000000    1.000000
# 1         2  1.272  1.773585    0.886792
# 2         3  0.849  2.657244    0.885748
# 3         4  0.990  2.278788    0.569697
# 4         5  0.701  3.218260    0.643652
# 5         6  0.574  3.930314    0.655052
# 6         7  0.498  4.530120    0.647160
# 7         8  0.485  4.651546    0.581443
# 8         9  0.480  4.700000    0.522222
# 9        10  0.482  4.680498    0.468050
# 10       11  0.458  4.925764    0.447797
# 11       12  0.441  5.115646    0.426304

# %%
# %matplotlib inline

import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# sns.set(style="darkgrid")

df = pd.read_csv('res.csv', delimiter=',')
display(df)
plt.plot(df["Threads"], df["Time"])


# df = pd.read_csv('res2.csv', delimiter=',')
# display(df)
# plt.plot(df["N"], df["Time"])
# Out:
#     Threads   Time     Uskor  Efficiency
# 0         1  3.238  1.000000    1.000000
# 1         2  1.743  1.857717    0.928858
# 2         3  1.349  2.400297    0.800099
# 3         4  1.116  2.901434    0.725358
# 4         5  1.200  2.698333    0.539667
# 5         6  0.870  3.721839    0.620307
# 6         7  0.779  4.156611    0.593802
# 7         8  0.717  4.516039    0.564505
# 8         9  0.748  4.328877    0.480986
# 9        10  0.684  4.733918    0.473392
# 10       11  0.639  5.067293    0.460663
# 11       12  0.631  5.131537    0.427628
